# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt

# %%
chimet_raw = pd.read_csv("Data\Output\Chimet_hourly.csv")
windguru_raw = pd.read_csv("Data\Output\windguru_hourly.csv")
windguru_raw.rename(columns={'record_datetime':'date_time'}, inplace=True)
data=pd.merge(chimet_raw, windguru_raw, on='date_time')
data.rename(columns={'wind_speed':'chmt_spd','wind_direction':'chmt_dir','windspd':'wg_spd','winddir':'wg_dir'}, inplace=True)
data.head()
# Out:
#              date_time   chmt_spd   chmt_dir  wg_spd  wg_dir
# 0  2009-01-01 00:00:00  14.109091  51.909091     9.2    66.8
# 1  2009-01-01 01:00:00  14.400000  47.833333     9.6    72.4
# 2  2009-01-01 02:00:00  15.600000  52.000000     9.1    73.4
# 3  2009-01-01 03:00:00  14.690909  47.181818     8.4    74.1
# 4  2009-01-01 04:00:00  13.633333  50.750000     8.1    72.9

# %%
data=data.dropna()

# %%
start_time=4000
end_time=start_time+1000
plt.scatter(data['chmt_spd'][start_time:end_time], data['wg_spd'][start_time:end_time])
x=data['chmt_spd'].values
y=data['wg_spd'].values
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)), 'g')
plt.grid(linestyle='dashed')
plt.plot((0,40),(0,40),'k',linestyle ='--')
plt.xlim(0, 40)
plt.ylim(0,40)
plt.xlabel('Chimet')
plt.ylabel('Windguru')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #### rmse = sqrt(mean_squared_error(data['chmt_spd'], data['wg_spd']))
# mae = sqrt(mean_absolute_error(data['chmt_spd'], data['wg_spd']))
# print(rmse)
# print(mae)

# %%
start_time=15000
end_time=start_time+500
plt.figure(figsize=(14,8))
plt.plot(data['chmt_spd'][start_time:end_time],label='Chimet')
plt.plot(data['wg_spd'][start_time:end_time],label='Windguru')
plt.legend()
plt.xlabel('Hours')
plt.ylabel('Wind speed (knots)')
# Out:
# Text(0,0.5,'Wind speed (knots)')

# %%
bins = 40
plt.hist(data['chmt_spd'], bins, alpha=0.5, label='Chimet',  edgecolor='black', linewidth=0.5)
plt.hist(data['wg_spd'], bins, alpha=0.4, label='Windguru',  edgecolor='black', linewidth=0.5)
plt.legend(loc='upper right')

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
data=data.fillna(data.mean())

# %%
cols=list(data)
data_series=np.empty([21616,48,1])
for col in cols:
    temp1=list(data[col].values)
    temp2=series_to_supervised(temp1,36,12)
    print(temp2.shape)
    data_series=np.dstack((data_series, temp2))
# Out:
# (21616, 48)
# (21616, 48)
# (21616, 48)
# (21616, 48)
# (21616, 48)

# %%
'''
This has created a numpy array with dimensions
    1. Each window (i.e. separate instance of t-36 to t+12)
    2. t-36 to t +12
    3: Variable (Date, WGspd, etc)
'''
data_series.shape
# Out:
# (21616, 48, 6)

# %%
# remove empty first column of zeros
data_series2= np.delete(data_series, 0, axis=2)
data_SW10=data_series2

# this loop breaks when it reaches new size of data_SW10 once data has been removed
# should find neater way to deal with this

for i in range(0,data_series.shape[0]):
    # delete window (first dim) if average speed in less than 10 knots
    if np.mean(data_SW10[i,:36,1]) < 10:
        data_SW10=np.delete(data_SW10,i,axis=0)
    # delete window (first dim) if average direction isn't in SW +/- 90deg (135,315) range
    elif np.mean(data_SW10[i,:36,2]) < 135:
        data_SW10=np.delete(data_SW10,i,axis=0)
    elif np.mean(data_SW10[i,:36,2]) > 315:
        data_SW10=np.delete(data_SW10,i,axis=0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-1216b6cc279c> in <module>()
#       5 for i in range(0,data_series.shape[0]):
#       6     # delete window (first dim) if average speed in less than 10 knots
# ----> 7     if np.mean(data_SW10[i,:36,1]) < 10:
#       8         data_SW10=np.delete(data_SW10,i,axis=0)
#       9     # delete window (first dim) if average direction isn't in SW +/- 90deg (135,315) range
#
# IndexError: index 16721 is out of bounds for axis 0 with size 16721

# %%
data_SW10.shape
# Out:
# (16721, 48, 5)

# %%
np.save('data_SW10', data_SW10)

# %%
help(data_series2)

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
split_point=len(data['chmt_spd'])-24
training=data['chmt_spd'][0:split_point]
testing=data['chmt_spd'][split_point:]
model = ARIMA(training, order=(10,1,1))
model_fit = model.fit()

# %%
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())

# %%
forecast=model_fit.forecast(24)
plt.plot(forecast[0])
plt.plot(testing.values.tolist())

# %%
print(testing.values.tolist())
